# %%
# !pip install networkx

# %%
# !pip install powerlaw

# %%
import networkx as nx
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import powerlaw
warnings.filterwarnings('ignore')

# %%
import networkx as nx
import matplotlib.pyplot as plt

# 400 оройтой, хоёр орой хооронд 5% магадлалтай санамсаргүй граф үүсгэх
er = nx.erdos_renyi_graph(400, 0.05)

# Графыг дүрслэх (node_size-г тохируулснаар оройны хэмжээ өөрчлөгдөж болно)
nx.draw(er, node_size=20)
plt.show()

# %%
# network generators 1 (random graphs)
er = nx.erdos_renyi_graph(400, 0.05)
nx.draw(er)

# %%
hist = nx.degree_histogram(er)

plt.plot(range(0, len(hist)), hist, ".")
plt.title("Degree Distribution")
plt.xlabel("Degree")
plt.ylabel("#Nodes")
plt.show()

# %%
er = nx.erdos_renyi_graph(100, 0.005)
nx.draw(er)

# %%
er = nx.erdos_renyi_graph(100, 0.01)
nx.draw(er)

# %%
er = nx.erdos_renyi_graph(100, 0.02)
nx.draw(er)

# %%
er = nx.erdos_renyi_graph(100, 0.06)
nx.draw(er)

# %%
g = nx.read_edgelist("/content/network.csv", delimiter=",", nodetype=int)

# %%
# fitting the degree distribution of the real graph

# %%
sequence = [i[1] for i in g.degree()]
cm = nx.configuration_model(sequence)

# %%
hist_o = nx.degree_histogram(g)
hist = nx.degree_histogram(cm)

fig = plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
plt.plot(range(0, len(hist_o)), hist_o, ".")
plt.title("Degree Distribution Real Graph")
plt.xlabel("Degree")
plt.ylabel("#Nodes")
plt.loglog()

plt.subplot(1, 2, 2)
plt.plot(range(0, len(hist)), hist, ".")
plt.title("Degree Distribution Configuration Model")
plt.xlabel("Degree")
plt.ylabel("#Nodes")
plt.loglog()
plt.show()
